# %%
# render plots as static figures in the notebook
# %matplotlib inline
# alternatively, for interactive in-notebook figures, use %pylab notebook
# optional adjustment for retina displays
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import os
import pandas as pd
from astropy import wcs

# %%
print("Yo, ho, ho!")
# Out:
# Yo, ho, ho!

# %%
np.random.seed(0) # for reproducibility

N = 50
x = np.random.rand(N) # random sample of N values from a uniform distribution
y = np.random.rand(N)
colors = np.random.rand(N)
area = (25 * np.random.rand(N))**2  # 0 to 25 point radii

fig, ax = plt.subplots(1)
ax.scatter(x, y, s=area, c=colors, alpha=0.5)
